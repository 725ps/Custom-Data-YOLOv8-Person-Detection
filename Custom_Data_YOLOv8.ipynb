# %% [markdown]
# <a href="https://colab.research.google.com/github/725ps/Custom-Data-YOLOv8-Person-Detection/blob/main/Custom_Data_YOLOv8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 949.8/949.8 kB 16.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 46.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 85.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 50.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 10.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 38.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 17.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 3.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 95.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
# !git clone https://github.com/SMSajadi99/Custom-Data-YOLOv8-Person-Detection.git
# Out:
# Cloning into 'Custom-Data-YOLOv8-Person-Detection'...
# remote: Enumerating objects: 46663, done.
# remote: Counting objects: 100% (15291/15291), done.
# remote: Compressing objects: 100% (13996/13996), done.
# remote: Total 46663 (delta 61), reused 15233 (delta 25), pack-reused 31372 (from 1)
# Receiving objects: 100% (46663/46663), 1.48 GiB | 13.10 MiB/s, done.
# Resolving deltas: 100% (67/67), done.
# Updating files: 100% (38455/38455), done.

# %%
# !nvidia-smi
# Out:
# Wed Mar 26 17:18:21 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA A100-SXM4-40GB          Off |   00000000:00:04.0 Off |                    0 |
# | N/A   28C    P0             43W /  400W |       0MiB /  40960MiB |      0%      Default |
# |                                         |                        |             Disabled |
# ...

# %%
# !yolo task=detect mode=train model=yolov8s.pt data=/content/Custom-Data-YOLOv8-Person-Detection/custom.yaml epochs=25 imgsz=640
# Out:
# Ultralytics 8.3.96 🚀 Python-3.11.11 torch-2.6.0+cu124 CUDA:0 (NVIDIA A100-SXM4-40GB, 40507MiB)
# ...

# %%
# !yolo task=detect mode=predict model="/content/runs/detect/train2/weights/last.pt" source="/content/Custom-Data-YOLOv8-Person-Detection/images/test/000067.jpg"
# Out:
# Ultralytics 8.3.96 🚀 Python-3.11.11 torch-2.6.0+cu124 CUDA:0 (NVIDIA A100-SXM4-40GB, 40507MiB)
# Model summary (fused): 72 layers, 11,125,971 parameters, 0 gradients, 28.4 GFLOPs
#
# image 1/1 /content/Custom-Data-YOLOv8-Person-Detection/images/test/000067.jpg: 352x640 19 Persons, 50.5ms
# Speed: 6.5ms preprocess, 50.5ms inference, 169.8ms postprocess per image at shape (1, 3, 352, 640)
# Results saved to runs/detect/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# !gdown "https://drive.google.com/uc?id=1wQXMEiq9txLsTnGFLXsUFbhlsMhoRPcA"
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1wQXMEiq9txLsTnGFLXsUFbhlsMhoRPcA
# To: /content/ps_test_1.mp4
# 100% 5.68M/5.68M [00:00<00:00, 45.4MB/s]

# %%
#!yolo task=detect mode=predict model="/content/runs/detect/train/weights/last.pt" source="/content/Person.mp4"
# !yolo task=detect mode=predict model="/content/runs/detect/train2/weights/last.pt" source="/content/ps_test_1.mp4"
# Out:
# Ultralytics 8.3.96 🚀 Python-3.11.11 torch-2.6.0+cu124 CUDA:0 (NVIDIA A100-SXM4-40GB, 40507MiB)
# Model summary (fused): 72 layers, 11,125,971 parameters, 0 gradients, 28.4 GFLOPs
#
# video 1/1 (frame 1/730) /content/ps_test_1.mp4: 288x640 (no detections), 49.5ms
# video 1/1 (frame 2/730) /content/ps_test_1.mp4: 288x640 (no detections), 7.4ms
# video 1/1 (frame 3/730) /content/ps_test_1.mp4: 288x640 (no detections), 7.0ms
# video 1/1 (frame 4/730) /content/ps_test_1.mp4: 288x640 (no detections), 7.0ms
# video 1/1 (frame 5/730) /content/ps_test_1.mp4: 288x640 (no detections), 7.0ms
# video 1/1 (frame 6/730) /content/ps_test_1.mp4: 288x640 (no detections), 6.9ms
# video 1/1 (frame 7/730) /content/ps_test_1.mp4: 288x640 (no detections), 6.9ms
# video 1/1 (frame 8/730) /content/ps_test_1.mp4: 288x640 (no detections), 6.9ms
# video 1/1 (frame 9/730) /content/ps_test_1.mp4: 288x640 (no detections), 6.9ms
# video 1/1 (frame 10/730) /content/ps_test_1.mp4: 288x640 (no detections), 6.9ms
# ...
